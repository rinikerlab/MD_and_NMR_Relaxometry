# %% [markdown]
# Notebook to visualize the Dynamic Detector Analysis

# %%
import pyDR
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
resids=[3, 5, 7, 8, 13, 23, 30, 36, 44, 61]
ile_resn = [3, 13, 23, 30, 36, 44, 61]

# %%
df_rhoz = pd.read_csv("rhoz.csv")

# %%
fig, ax = plt.subplots()
ax.plot(df_rhoz.tc,df_rhoz.ile_3_1,label='rho1')
ax.plot(df_rhoz.tc,df_rhoz.ile_3_2,label='rho2')
ax.plot(df_rhoz.tc,df_rhoz.ile_3_3,label='rho3')
ax.plot(df_rhoz.tc,df_rhoz.ile_3_4,label='rho4')
ax.set_xlabel('tc')
ax.set_xscale('log')
ax.set_ylabel('rho')
ax.legend()

# %%
fig, ax = plt.subplots()
for i, leu_i in enumerate(ile_resn):
    ax.plot(df_rhoz.tc,df_rhoz[f"ile_{leu_i}_1"],label=f'rho1_{leu_i}', color=f'C{i}')
    ax.plot(df_rhoz.tc,df_rhoz[f"ile_{leu_i}_2"], color=f'C{i}', linestyle=':')
ax.set_xlabel('tc')
ax.set_xscale('log')
ax.set_ylabel('rho')
ax.legend()

# %%
fig, ax = plt.subplots()
for i, leu_i in enumerate(ile_resn):
    ax.plot(df_rhoz.tc,df_rhoz[f"sum_{leu_i}"],label=f'sum_{leu_i}', color=f'C{i}')
ax.set_xlabel('tc')
ax.set_xscale('log')
ax.set_ylabel('rho')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(dyn_dec_tc,df_rhoz.ile_44_1, label='rho1', color='C0')
ax.plot(dyn_dec_tc,df_rhoz.ile_44_2, label='rho2', color='C1')
ax.plot(dyn_dec_tc,df_rhoz.ile_44_3, label='rho3', color='C2')
ax.plot(dyn_dec_tc,df_rhoz.ile_44_4, label='rho4', color='C3')
ax.set_xlabel('tc')
ax.set_xscale('log')
ax.set_ylabel('rho')
max_height = 1.1 * max(dyn_dec_rho_1)
ax.vlines(1.8e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax.vlines(1.0e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax.vlines(0.1e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax.vlines(0.3e-9,0,max_height,linestyle=':',label='MF (single)', color='C5')
ax.vlines(0.07e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax.vlines(1.05e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax.vlines(0.11e-9,0,max_height,linestyle='dashdot',label='ROMANCE', color='C7')
ax.set_xlim(1e-11,1e-7)
ax.set_ylim(0,max_height)
ax.legend(bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=4)
# label plot with ILE 44 in the top left corner
ax.text(0.03, 0.95, 'ILE 44', transform=ax.transAxes, fontsize=16,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))
plt.savefig('exp_v_simLeu3_ile44.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(dyn_dec_tc,df_rhoz.ile_13_1, label='rho1', color='C0')
ax.plot(dyn_dec_tc,df_rhoz.ile_13_2, label='rho2', color='C1')
ax.plot(dyn_dec_tc,df_rhoz.ile_13_3, label='rho3', color='C2')
ax.plot(dyn_dec_tc,df_rhoz.ile_13_4, label='rho4', color='C3')
ax.set_xlabel('tc')
ax.set_xscale('log')
ax.set_ylabel('rho')
max_height = 1.1 * max(dyn_dec_rho_1)
ax.vlines(3.6e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax.vlines(0.6e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax.vlines(0.2e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax.vlines(0.15e-9,0,max_height,linestyle=':',label='MF (single)', color='C5')
ax.vlines(0.08e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax.vlines(3.0e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax.vlines(1.9e-9,0,max_height,linestyle='dashdot',label='ROMANCE', color='C7')
ax.set_xlim(1e-11,1e-7)
ax.set_ylim(0,max_height)
ax.legend(bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=4)
ax.text(0.03, 0.95, 'ILE 13', transform=ax.transAxes, fontsize=16,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))
plt.savefig('exp_v_simLeu3_ile13.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(dyn_dec_tc,df_rhoz.ile_36_1, label='rho1', color='C0')
ax.plot(dyn_dec_tc,df_rhoz.ile_36_2, label='rho2', color='C1')
ax.plot(dyn_dec_tc,df_rhoz.ile_36_3, label='rho3', color='C2')
ax.plot(dyn_dec_tc,df_rhoz.ile_36_4, label='rho4', color='C3')
ax.set_xlabel('tc')
ax.set_xscale('log')
ax.set_ylabel('rho')
max_height = 1.1 * max(dyn_dec_rho_1)
ax.vlines(0.1e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax.vlines(0.6e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax.vlines(5.0e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax.vlines(0.2e-9,0,max_height,linestyle=':',label='MF (single)', color='C5')
ax.vlines(0.09e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax.vlines(1.8e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax.vlines(2.0e-9,0,max_height,linestyle='dashdot',label='ROMANCE', color='C7')
ax.set_xlim(1e-11,1e-7)
ax.set_ylim(0,max_height)
ax.legend(bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=4)
ax.text(0.03, 0.95, 'ILE 36', transform=ax.transAxes, fontsize=16,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))
plt.savefig('exp_v_simLeu3_ile36.pdf', bbox_inches='tight')

# %%
# plot for ILE 13, 36 and 44
fig, ax = plt.subplots(1, 3, figsize=(15,5))

ax[0].plot(dyn_dec_tc,df_rhoz.ile_13_1, label=r'$\rho$1', color='C0')
ax[0].plot(dyn_dec_tc,df_rhoz.ile_13_2, label=r'$\rho$1', color='C1')
ax[0].plot(dyn_dec_tc,df_rhoz.ile_13_3, label=r'$\rho$1', color='C2')
ax[0].plot(dyn_dec_tc,df_rhoz.ile_13_4, label=r'$\rho$1', color='C3')
ax[0].set_xlabel('tc')
ax[0].set_xscale('log')
ax[0].set_ylabel('rho')
max_height = 1.1 * max(dyn_dec_rho_1)
ax[0].vlines(3.6e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax[0].vlines(0.6e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax[0].vlines(0.2e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax[0].vlines(0.15e-9,0,max_height,linestyle=':',label='MF (single)', color='C5')
ax[0].vlines(0.08e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax[0].vlines(3.0e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax[0].vlines(1.9e-9,0,max_height,linestyle='dashdot',label='ROMANCE', color='C7')
ax[0].set_xlim(1e-11,1e-7)
ax[0].set_ylim(0,max_height)
#ax[0].legend(bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=4)
ax[0].text(0.03, 0.95, 'ILE 13', transform=ax[0].transAxes, fontsize=16,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

ax[1].plot(dyn_dec_tc,df_rhoz.ile_36_1, label=r'$\rho$1', color='C0')
ax[1].plot(dyn_dec_tc,df_rhoz.ile_36_2, label=r'$\rho$2', color='C1')
ax[1].plot(dyn_dec_tc,df_rhoz.ile_36_3, label=r'$\rho$3', color='C2')
ax[1].plot(dyn_dec_tc,df_rhoz.ile_36_4, label=r'$\rho$4', color='C3')
ax[1].set_xlabel('tc')
ax[1].set_xscale('log')
ax[1].set_ylabel('rho')
max_height = 1.1 * max(dyn_dec_rho_1)
ax[1].vlines(0.1e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax[1].vlines(0.6e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax[1].vlines(5.0e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax[1].vlines(0.2e-9,0,max_height,linestyle=':',label='MF (single)', color='C5')
ax[1].vlines(0.09e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax[1].vlines(1.8e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax[1].vlines(2.0e-9,0,max_height,linestyle='dashdot',label='ROMANCE', color='C7')
ax[1].set_xlim(1e-11,1e-7)
ax[1].set_ylim(0,max_height)
#ax[1].legend(bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=4)
ax[1].text(0.03, 0.95, 'ILE 36', transform=ax[1].transAxes, fontsize=16,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

ax[2].plot(dyn_dec_tc, df_rhoz.ile_44_1, label='rho1', color='C0')
ax[2].plot(dyn_dec_tc, df_rhoz.ile_44_2, label='rho2', color='C1')
ax[2].plot(dyn_dec_tc, df_rhoz.ile_44_3, label='rho3', color='C2')
ax[2].plot(dyn_dec_tc, df_rhoz.ile_44_4, label='rho4', color='C3')
ax[2].set_xlabel('tc')
ax[2].set_xscale('log')
ax[2].set_ylabel('rho')
max_height = 1.1 * max(dyn_dec_rho_1)
ax[2].vlines(1.8e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax[2].vlines(1.0e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax[2].vlines(0.1e-9,0,max_height,linestyle='--',label='MFPTs (MSM)', color='C4')
ax[2].vlines(0.3e-9,0,max_height,linestyle=':',label='MF (single)', color='C5')
ax[2].vlines(0.07e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax[2].vlines(1.05e-9,0,max_height,linestyle=':',label='MF (double)', color='C6')
ax[2].vlines(0.11e-9,0,max_height,linestyle='dashdot',label='ROMANCE', color='C7')
ax[2].set_xlim(1e-11,1e-7)
ax[2].set_ylim(0,max_height)
#ax[2].legend(bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=4)
ax[2].text(0.03, 0.95, 'ILE 44', transform=ax[2].transAxes, fontsize=16,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

# legend for all three plots below, outside of the plots, centered
ax[1].legend(bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=6)
plt.savefig('exp_v_simLeu3_ile13_36_44.pdf', bbox_inches='tight')
